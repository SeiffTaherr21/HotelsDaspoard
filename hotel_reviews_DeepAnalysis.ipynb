# %% [markdown]
# | Column Name | Description |
# |------------|-------------|
# | Hotel Address | Full address of the hotel; can be used to derive city and country. |
# | Additional Number of Scoring | Extra number of scores previously given by the reviewer. |
# | Review Date | Date on which the review was written. |
# | Average Score | Average user rating for the hotel. |
# | Hotel Name | Name of the hotel reviewed. |
# | Reviewer Nationality | Nationality of the reviewer. |
# | Negative Review | Text content of the negative feedback. |
# | Review Total Negative Word Counts | Number of negative words present in the negative review. |
# | Total Number of Reviews Reviewer Has Given | Total reviews submitted by this reviewer before. |
# | Positive Review | Text content of the positive feedback. |
# | Review Total Positive Word Counts | Number of positive words in the positive review. |
# | Total Number of Reviews | Total number of reviews for the hotel. |
# | Country | Country where the hotel is located. |
# | City | City where the hotel is located. |
# | Reviewer Level | Experience or classification level of the reviewer. |
# | Nights Stayed | Number of nights the guest stayed at the hotel. |
# | Traveler Type | Type of traveler (Solo, Couple, Family, Group). |
# | Trip Type | Purpose of the trip (Business, Leisure, etc.). |
# | Room Type | Specific type of room booked. |
# | Review Year | Year extracted from the review date. |
# | Review Month | Month extracted from the review date. |
# | Review Day | Day extracted from the review date. |
# | Season | Season of the year the review belongs to. |
# | Hotel Popularity Score | Custom score reflecting hotel popularity. |
# | Sentiment Label | Sentiment classification (Positive, Negative, Neutral). |
# | Stay Length Category | Categorized version of nights stayed. |
# | Room Type Category | Grouped/standardized version of room types. |

# %%
import pandas as pd
import plotly.express as px 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.io as pio

# %%
df = pd.read_csv('hotel_reviews_edited.csv')
df
# Out:
#                                            Hotel Address  \
# 0                     43 Rue des Mathurins 8th arr 75008
# 1                     Provincialeweg 38 Zuidoost 1108 AB
# 2                  Jan Luijkenstraat 76 Oud Zuid 1071 CT
# 3      No 1 Seething Lane City of London London EC3N 4AX
# 4               Plaza de Catalunya 19 Ciutat Vella 08002
# ...                                                  ...
# 14383        Piazza Duca D Aosta 9 Central Station 20124
# 14384                  5 bis rue Massenet 16th arr 75016
# 14385  Mandeville Place Westminster Borough London W1...
# 14386  2 24 Kensington High St Kensington and Chelsea...
# 14387                     Kirchengasse 41 07 Neubau 1070
#
#        Additional Number of Scoring Review Date  Average Score  \
# 0                               135  2016-04-11            8.6
# 1                               245  2016-07-26            7.5
# 2                               146  2016-02-09            8.8
# 3                               623  2016-07-07            9.0
# 4                               315  2015-08-05            9.3
# ...                             ...         ...            ...
# 14383                           185  2015-11-19            9.4
# 14384                            38  2017-08-03            8.0
# 14385                           495  2016-03-15            8.5
# 14386                           617  2016-03-20            8.8
# 14387                            69  2016-09-20            9.3
#
#                                            Hotel Name  \
# 0                               Le Mathurin Hotel Spa
# 1                    Golden Tulip Amsterdam Riverside
# 2                                       Hotel JL No76
# 3                           Apex City Of London Hotel
# 4                                  Olivia Plaza Hotel
# ...                                               ...
# 14383  Excelsior Hotel Gallia Luxury Collection Hotel
# 14384          Best Western Premier Trocadero La Tour
# 14385                            The Mandeville Hotel
# 14386                              Royal Garden Hotel
# 14387              Small Luxury Hotel Altstadt Vienna
#
#            Reviewer Nationality  \
# 0                       Germany
# 1                United Kingdom
# 2                       Ireland
# 3                       Germany
# 4                  Saudi Arabia
# ...                         ...
# 14383                  Pakistan
# 14384            United Kingdom
# 14385            United Kingdom
# 14386              Saudi Arabia
# 14387  United States of America
#
#                                          Negative Review  \
# 0                                            No Negative
# 1       the location wasnt very good it was 20 minute...
# 2                                            No Negative
# 3       Even though it was a nice hotel it s not real...
# 4                              every thing was very good
# ...                                                  ...
# 14383                                        No Negative
# 14384   The hotel was full so we had a room right in ...
# 14385                                                N a
# 14386   we had to leave after 10 days wished our stay...
# 14387   Glass doors in the bathroom I know it s quirk...
#
#        Review Total Negative Word Counts  Total Number of Reviews  \
# 0                                      0                     1184
# 1                                     67                     2362
# 2                                      0                      914
# 3                                     38                     2750
# 4                                      6                     2757
# ...                                  ...                      ...
# 14383                                  0                     1345
# 14384                                 22                      216
# 14385                                  3                     2300
# 14386                                 13                     2213
# 14387                                 19                      664
#
#                                          Positive Review  ...      Trip Type  \
# 0       Great Rooms with a nice bathroom Room was pre...  ...   Leisure trip
# 1       The hotel was lovely would have to say it sho...  ...   Leisure trip
# 2       The hotel is well located near the Museum Qua...  ...   Leisure trip
# 3                   Staff was very helpful and friendly   ...   Leisure trip
# 4       The reception people was very good in receivi...  ...   Leisure trip
# ...                                                  ...  ...            ...
# 14383                                   service was good  ...  Business trip
# 14384   The bed WAS extra comfy The breakfast was the...  ...  Business trip
# 14385   Very quiet air conditioning Comfortable and e...  ...   Leisure trip
# 14386   every thing in this hotel is perfect location...  ...   Leisure trip
# 14387   Everything the attention to detail making you...  ...   Leisure trip
#
#                          Room Type  Review Year  Review Month  Review Day  \
# 0      Classic Double or Twin Room         2016             4          11
# 1               Standard Twin Room         2016             7          26
# 2      Comfort Double or Twin Room         2016             2           9
# 3               Deluxe Family Room         2016             7           7
# 4                          2 rooms         2015             8           5
# ...                            ...          ...           ...         ...
# 14383           Luxury Double Room         2015            11          19
# 14384                 Classic Room         2017             8           3
# 14385         Superior Double Room         2016             3          15
# 14386                    Twin Room         2016             3          20
# 14387           Deluxe Double Room         2016             9          20
#
#        Season Hotel Popularity Score Sentiment Label  Stay Length Category  \
# 0      Spring                10182.4        Positive            Short Stay
# 1      Summer                17715.0        Positive           Medium Stay
# 2      Winter                 8043.2        Positive           Medium Stay
# 3      Summer                24750.0        Negative           Medium Stay
# 4      Summer                25640.1        Positive           Medium Stay
# ...       ...                    ...             ...                   ...
# 14383  Autumn                12643.0        Positive            Short Stay
# 14384  Summer                 1728.0        Negative           Medium Stay
# 14385  Winter                19550.0        Positive            Short Stay
# 14386  Spring                19474.4        Positive             Long Stay
# 14387  Summer                 6175.2        Positive           Medium Stay
#
#       Room Type Category
# 0                 Double
# 1                  Other
# 2                 Double
# 3                 Family
# 4                  Other
# ...                  ...
# 14383             Double
# 14384     Deluxe/Comfort
# 14385             Double
# 14386              Other
# 14387             Double
#
# [14388 rows x 30 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                        Hotel Address  \
# 0                 43 Rue des Mathurins 8th arr 75008
# 1                 Provincialeweg 38 Zuidoost 1108 AB
# 2              Jan Luijkenstraat 76 Oud Zuid 1071 CT
# 3  No 1 Seething Lane City of London London EC3N 4AX
# 4           Plaza de Catalunya 19 Ciutat Vella 08002
#
#    Additional Number of Scoring Review Date  Average Score  \
# 0                           135  2016-04-11            8.6
# 1                           245  2016-07-26            7.5
# 2                           146  2016-02-09            8.8
# 3                           623  2016-07-07            9.0
# 4                           315  2015-08-05            9.3
#
#                          Hotel Name Reviewer Nationality  \
# 0             Le Mathurin Hotel Spa              Germany
# 1  Golden Tulip Amsterdam Riverside       United Kingdom
# 2                     Hotel JL No76              Ireland
# 3         Apex City Of London Hotel              Germany
# 4                Olivia Plaza Hotel         Saudi Arabia
#
#                                      Negative Review  \
# 0                                        No Negative
# 1   the location wasnt very good it was 20 minute...
# 2                                        No Negative
# 3   Even though it was a nice hotel it s not real...
# 4                          every thing was very good
#
#    Review Total Negative Word Counts  Total Number of Reviews  \
# 0                                  0                     1184
# 1                                 67                     2362
# 2                                  0                      914
# 3                                 38                     2750
# 4                                  6                     2757
#
#                                      Positive Review  \
# 0   Great Rooms with a nice bathroom Room was pre...
# 1   The hotel was lovely would have to say it sho...
# 2   The hotel is well located near the Museum Qua...
# 3               Staff was very helpful and friendly
# 4   The reception people was very good in receivi...
#
#    Review Total Positive Word Counts  \
# 0                                 40
# 1                                 68
# 2                                 18
# 3                                  8
# 4                                 33
#
#    Total Number of Reviews Reviewer Has Given  days since review        lat  \
# 0                                          12                479  48.873207
# 1                                           1                373  52.315453
# 2                                           5                541  52.359592
# 3                                           7                392  51.510462
# 4                                           7                729  41.386146
#
#         lng      Country       City Reviewer Level  Nights Stayed  \
# 0  2.323901       France      Paris           High            2.0
# 1  4.996300  Netherlands  Amsterdam   Intermediate            3.0
# 2  4.880159  Netherlands  Amsterdam   Intermediate            3.0
# 3 -0.079550      Kingdom     United   Intermediate            3.0
# 4  2.171159        Spain  Barcelona           High            4.0
#
#                 Traveler Type     Trip Type                    Room Type  \
# 0                      Couple  Leisure trip  Classic Double or Twin Room
# 1                      Couple  Leisure trip           Standard Twin Room
# 2                      Couple  Leisure trip  Comfort Double or Twin Room
# 3  Family with young children  Leisure trip           Deluxe Family Room
# 4  Family with young children  Leisure trip                      2 rooms
#
#    Review Year  Review Month  Review Day  Season  Hotel Popularity Score  \
# 0         2016             4          11  Spring                 10182.4
# 1         2016             7          26  Summer                 17715.0
# 2         2016             2           9  Winter                  8043.2
# 3         2016             7           7  Summer                 24750.0
# 4         2015             8           5  Summer                 25640.1
#
#   Sentiment Label Stay Length Category Room Type Category
# 0        Positive           Short Stay             Double
# 1        Positive          Medium Stay              Other
# 2        Positive          Medium Stay             Double
# 3        Negative          Medium Stay             Family
# 4        Positive          Medium Stay              Other

# %% [markdown]
# ## **Group 1 — Hotel Performance & Popularity**

# %% [markdown]
# **Q1 Which cities show the best trade-off between **High Average Score** and **Low Total Number of Reviews** .**

# %%
city_avg_score = df.groupby('City', as_index=False)['Average Score'].mean()
city_avg_score
# Out:
#         City  Average Score
# 0  Amsterdam       8.400121
# 1  Barcelona       8.512718
# 2      Milan       8.438704
# 3      Paris       8.394913
# 4     United       8.345692
# 5     Vienna       8.580101

# %%
city_total_reviews = df.groupby('City', as_index=False)['Total Number of Reviews'] \
                       .sum() \
                       .sort_values(by='Total Number of Reviews', ascending=True)
city_total_reviews
# Out:
#         City  Total Number of Reviews
# 3      Paris                  2179785
# 5     Vienna                  2333310
# 2      Milan                  3562029
# 1  Barcelona                  4067191
# 0  Amsterdam                  5724476
# 4     United                 21948646

# %%
city_stats = city_avg_score.merge(city_total_reviews, on='City')
city_stats
# Out:
#         City  Average Score  Total Number of Reviews
# 0  Amsterdam       8.400121                  5724476
# 1  Barcelona       8.512718                  4067191
# 2      Milan       8.438704                  3562029
# 3      Paris       8.394913                  2179785
# 4     United       8.345692                 21948646
# 5     Vienna       8.580101                  2333310

# %%
px.scatter(
    city_stats,
    x='Total Number of Reviews',
    y='Average Score',
    text='City',  
    # height=500 , width=750,
    size='Total Number of Reviews',  
    color='Total Number of Reviews',
    title='Cities with High Average Score and Low Total Reviews'
).update_traces(textposition='top center')

# %% [markdown]
# **Q3 What are the top 5 countries/cities that provide the highest average **Review Total Positive Word Counts**?**

# %%
top_6 =(df.groupby(['Country', 'City'])['Review Total Positive Word Counts'] \
    .mean() \
    .reset_index() \
    .sort_values(by='Review Total Positive Word Counts', ascending=False)
)
top_6
# Out:
#        Country       City  Review Total Positive Word Counts
# 4  Netherlands  Amsterdam                          20.262840
# 0      Austria     Vienna                          19.582828
# 5        Spain  Barcelona                          18.513937
# 2        Italy      Milan                          18.237369
# 1       France      Paris                          17.599641
# 3      Kingdom     United                          16.224764

# %%
top_6['City_Country'] = top_6['City'] + " (" + top_6['Country'] + ")"

# %%
px.bar(
    top_6,
    x="City_Country",
    y="Review Total Positive Word Counts",
    color="Review Total Positive Word Counts",
    # color_continuous_scale="Viridis",
    title="Top 6 Countries/Cities by Average Positive Word Counts",text_auto=True
).update_layout(
    xaxis_title="City (Country)",
    yaxis_title="Average Positive Word Count",
    # height=600
)

# %% [markdown]
# **Q4 What is the geographical spread of hotels that have a poor average score (e.g., below 7.5)?**

# %%
poor_hotels = df[df['Average Score'] < 7.5]

poor_hotels_unique = (
    poor_hotels
    .groupby('Hotel Name')[['Average Score', 'Hotel Address', 'City', 'Country', 'lat', 'lng']]
    .first()
    .reset_index()
    .sort_values(by='Average Score')
    .head(30)
)
poor_hotels_unique
# Out:
#                                       Hotel Name  Average Score  \
# 24                               Hotel Cavendish            6.4
# 42                         Savoy Hotel Amsterdam            6.4
# 47                             The Tophams Hotel            6.6
# 5       Best Western Maitrise Hotel Edgware Road            6.6
# 11                               Commodore Hotel            6.7
# 48                                 Villa Eugenie            6.8
# 8                        Bloomsbury Palace Hotel            6.8
# 17  Hallmark Hotel London Chigwell Prince Regent            6.9
# 13                            Gainsborough Hotel            6.9
# 30                    Idea Hotel Milano San Siro            6.9
# 18                                    Henry VIII            7.0
# 27                           Hotel Royal Elys es            7.0
# 32                        London Elizabeth Hotel            7.0
# 14                            Gran Hotel Barcino            7.0
# 29                  IH Hotels Milano Lorenteggio            7.0
# 12                       Eurohotel Diagonal Port            7.0
# 36                          NH Carlton Amsterdam            7.0
# 38                          Park Lane Mews Hotel            7.0
# 31                             Ilunion Almirante            7.1
# 22        Holiday Inn Paris Montparnasse Pasteur            7.1
# 28                    Hyatt Regency Paris Etoile            7.1
# 2         BEST WESTERN Maitrise Hotel Maida Vale            7.1
# 9     Britannia International Hotel Canary Wharf            7.1
# 16                          H tel De Castiglione            7.2
# 4       Best Western Hotel Montmartre Sacr Coeur            7.2
# 1                           Amarante Beau Manoir            7.2
# 44         Shaftesbury Premier London Paddington            7.3
# 41                   Royal Garden Champs Elysees            7.3
# 6            Best Western Plus Hotel Blue Square            7.3
# 0                                  Admiral Hotel            7.3
#
#                                         Hotel Address       City      Country  \
# 24             75 Gower Street Camden London WC1E 6HJ     United      Kingdom
# 42           Ferdinand Bolstraat 194 Oud Zuid 1072 LW  Amsterdam  Netherlands
# 47  28 Ebury Street Westminster Borough London SW1...     United      Kingdom
# 5   346 348 Edgware Road Westminster Borough Londo...     United      Kingdom
# 11  50 Lancaster Gate Westminster Borough London W...     United      Kingdom
# 48                     167 rue de Rome 17th arr 75017      Paris       France
# 8           29 31 Gower Street Camden London WC1E 6HG     United      Kingdom
# 17                          Manor Road London IG8 8AE     United      Kingdom
# 13  7 11 Queensberry Place Kensington and Chelsea ...     United      Kingdom
# 30                      Via Gaetano Airaghi 125 20153      Milan        Italy
# 18  23 Leinster Gardens Westminster Borough London...     United      Kingdom
# 27                6 Avenue Victor Hugo 16th arr 75116      Paris       France
# 32  Lancaster Terrace Hyde Park Westminster Boroug...     United      Kingdom
# 14                       Jaume I 6 Ciutat Vella 08002  Barcelona        Spain
# 29              Via Lorenteggio 278 Lorenteggio 20152      Milan        Italy
# 12                     Lope de Vega 4 Sant Mart 08005  Barcelona        Spain
# 36       Vijzelstraat 4 Amsterdam City Center 1017 HK  Amsterdam  Netherlands
# 38  2 Stanhope Row Park Lane Westminster Borough L...     United      Kingdom
# 31                 Via Laietana 42 Ciutat Vella 08003  Barcelona        Spain
# 22               10 rue Gager Gabillot 15th arr 75015      Paris       France
# 28           3 Place du G n ral Koenig 17th arr 75017      Paris       France
# 2   53 59 Kilburn High Road Maida Vale London Camd...     United      Kingdom
# 9   163 Marsh Wall Docklands Tower Hamlets London ...     United      Kingdom
# 16      38 Rue Du Faubourg Saint Honore 8th arr 75008      Paris       France
# 4                  66 Boulevard Barb s 18th arr 75018      Paris       France
# 1                     6 Rue de l Arcade 8th arr 75008      Paris       France
# 44  55 61 Westbourne Terrace Westminster Borough L...     United      Kingdom
# 41     218 220 rue du Faubourg St Honor 8th arr 75008      Paris       France
# 6     Slotermeerlaan 80 Geuzenveld Slotermeer 1064 HD  Amsterdam  Netherlands
# 0          Via Domodossola 16 Fiera Milano City 20145      Milan        Italy
#
#           lat       lng
# 24  51.522052 -0.132414
# 42  52.349743  4.891191
# 47  51.495744 -0.147753
# 5   51.521148 -0.171346
# 11  51.512450 -0.179522
# 48  48.887128  2.314205
# 8   51.520795 -0.131084
# 17  51.606805  0.059042
# 13  51.494842 -0.177206
# 30  45.472065  9.077787
# 18  51.512465 -0.182274
# 27  48.872967  2.292623
# 32  51.512022 -0.176241
# 14  41.383058  2.177827
# 29  45.443613  9.116109
# 12  41.400671  2.208784
# 36  52.366373  4.893051
# 38  51.505933 -0.148942
# 31  41.386052  2.176157
# 22  48.837689  2.306310
# 28  48.880278  2.284385
# 2   51.536605 -0.191983
# 9   51.501910 -0.023221
# 16  48.869176  2.320581
# 4   48.888539  2.349846
# 1   48.870994  2.323533
# 44  51.515367 -0.178327
# 41  48.875715  2.303878
# 6   52.378682  4.820783
# 0   45.480515  9.160063

# %%
px.bar(
    poor_hotels_unique,
    x="Hotel Name",
    y="Average Score",
    color="Country",
    hover_data=["City", "Hotel Address"],
    title="Lowest 30 Hotels by Average Score",text_auto=True
).update_layout(xaxis_tickangle=-45)

# %% [markdown]
# **Q5 What is the overall distribution of hotels across countries based on the average score?**

# %%
country_avg_score = df.groupby('Country')['Average Score'].mean().reset_index()
country_counts = df.groupby('Country')['Hotel Name'].count().reset_index(name='Hotel Count')
country_data = pd.merge(country_avg_score, country_counts, on='Country')

# %%
px.scatter(
    country_data,
    x="Country",
    y="Average Score",
    size="Hotel Count",        
    color="Hotel Count",     
    hover_name="Country",
    hover_data=["Hotel Count", "Average Score"],
    title="Distribution of Hotels Across Countries by Average Score"
).update_layout(
    xaxis_tickangle=-45,       
    yaxis_title="Average Score",
    xaxis_title="Country",
    margin={"r":0,"t":30,"l":0,"b":0}
)

# %% [markdown]
# **Which hotels have the highest average review scores?**

# %%
df['Hotel Name'].nunique()
# Out:
# 1371

# %%
df.groupby('Hotel Name')['Average Score'].mean().reset_index().sort_values(by='Average Score',ascending=False).head(10)
# Out:
#                                Hotel Name  Average Score
# 465                       Haymarket Hotel            9.6
# 557                     Hotel Casa Camper            9.6
# 447                 H10 Casa Mimosa 4 Sup            9.6
# 708                      Hotel The Serras            9.6
# 438   H tel de La Tamise Esprit de France            9.6
# 3                                      41            9.6
# 823                 Le Narcisse Blanc Spa            9.5
# 1026               Palais Coburg Residenz            9.5
# 707             Hotel The Peninsula Paris            9.5
# 884                Mercer Hotel Barcelona            9.5

# %%
px.bar(
    df.groupby('Hotel Name')['Average Score'].mean().reset_index().sort_values(by='Average Score',ascending=False).head(10),
    x='Hotel Name', y='Average Score',text_auto=True ,
)

# %% [markdown]
# 2. **How does the hotel popularity score vary across different cities,country?**

# %%
country_city_popularity = df.groupby(['Country', 'City'])['Hotel Popularity Score'] \
                            .mean() \
                            .reset_index().sort_values(by='Hotel Popularity Score',ascending=False)
country_city_popularity
# Out:
#        Country       City  Hotel Popularity Score
# 4  Netherlands  Amsterdam            29164.867311
# 2        Italy      Milan            28394.268637
# 3      Kingdom     United            24845.892576
# 0      Austria     Vienna            20125.573434
# 5        Spain  Barcelona            19887.735250
# 1       France      Paris            10595.469898

# %%
px.bar(country_city_popularity.sort_values('Hotel Popularity Score', ascending=False),
             x='City', y='Hotel Popularity Score',
             color='Country',  
             text_auto=True)

# %% [markdown]
# **Is there a relationship between the total number of reviews and the average score?**

# %%
df[['Total Number of Reviews', 'Average Score']].corr()
# Out:
#                          Total Number of Reviews  Average Score
# Total Number of Reviews                 1.000000      -0.172534
# Average Score                          -0.172534       1.000000

# %%
px.scatter(df, 
                 x='Total Number of Reviews', 
                 y='Average Score',
                 hover_data=['Hotel Name'],  # لو تحب تشوف اسم الفندق عند المرور
                 trendline='ols')

# %% [markdown]
# **Which cities have the highest-rated hotels on average?**

# %%
df.groupby('City')['Average Score'].mean().reset_index().sort_values(by='Average Score',ascending=False)
# Out:
#         City  Average Score
# 5     Vienna       8.580101
# 1  Barcelona       8.512718
# 2      Milan       8.438704
# 0  Amsterdam       8.400121
# 3      Paris       8.394913
# 4     United       8.345692

# %%
px.bar(df.groupby('City')['Average Score'].mean().reset_index().sort_values(by='Average Score',ascending=False),
             x='City', y='Average Score',
             text_auto=True)

# %% [markdown]
# **Which hotels receive the highest number of total reviews?**

# %%
df.columns
# Out:
# Index(['Hotel Address', 'Additional Number of Scoring', 'Review Date',
#        'Average Score', 'Hotel Name', 'Reviewer Nationality',
#        'Negative Review', 'Review Total Negative Word Counts',
#        'Total Number of Reviews', 'Positive Review',
#        'Review Total Positive Word Counts',
#        'Total Number of Reviews Reviewer Has Given', 'days since review',
#        'lat', 'lng', 'Country', 'City', 'Reviewer Level', 'Nights Stayed',
#        'Traveler Type', 'Trip Type', 'Room Type', 'Review Year',
#        'Review Month', 'Review Day', 'Season', 'Hotel Popularity Score',
#        'Sentiment Label', 'Stay Length Category', 'Room Type Category'],
#       dtype='object')

# %%
top_hotels = df.groupby('Hotel Name')['Total Number of Reviews'].sum().reset_index().sort_values(by='Total Number of Reviews',ascending=False).head(20)
top_hotels
# Out:
#                                              Hotel Name  \
# 1051               Park Plaza Westminster Bridge London
# 1186                                Strand Palace Hotel
# 173          Britannia International Hotel Canary Wharf
# 227              Copthorne Tara Hotel London Kensington
# 568                                      Hotel Da Vinci
# 263   DoubleTree by Hilton Hotel London Tower of London
# 347                       Grand Royale London Hyde Park
# 146                  Best Western Premier Hotel Couture
# 496                       Holiday Inn London Kensington
# 481                             Hilton London Metropole
# 164                                 Blakemore Hyde Park
# 739                              Hotel degli Arcimboldi
# 1287                   The Student Hotel Amsterdam City
# 1043                      Park Plaza County Hall London
# 929                  Millennium Gloucester Hotel London
# 1036                        Park Grand Paddington Court
# 328                         Golden Tulip Amsterdam West
# 1090                     Ramada Apollo Amsterdam Centre
# 768                      Intercontinental London The O2
# 858           M by Montcalm Shoreditch London Tech City
#
#       Total Number of Reviews
# 1051                  1544066
# 1186                  1301248
# 173                   1090320
# 227                    774445
# 568                    733480
# 263                    719136
# 347                    542737
# 146                    482443
# 496                    475600
# 481                    460482
# 164                    455124
# 739                    433680
# 1287                   398112
# 1043                   385371
# 929                    383642
# 1036                   376656
# 328                    356542
# 1090                   300040
# 768                    294280
# 858                    292922

# %%
px.bar(top_hotels,
             x='Hotel Name',
             y='Total Number of Reviews',
             text_auto=True)

# %% [markdown]
# ## **Group 2 — Reviewer Behavior & Demographics**

# %% [markdown]
# **Which reviewer nationalities give the highest scores on average?**

# %%
nationality_avg = df.groupby('Reviewer Nationality')['Average Score'].mean().reset_index().sort_values(by='Average Score',ascending=False).head(20)
nationality_avg
# Out:
#       Reviewer Nationality  Average Score
# 21                  Brunei       9.300000
# 124                Tunisia       9.100000
# 118                  Syria       9.000000
# 19                Botswana       9.000000
# 3                  Andorra       9.000000
# 14                Barbados       8.950000
# 74           Liechtenstein       8.900000
# 95   Palestinian Territory       8.900000
# 87                 Namibia       8.875000
# 97                    Peru       8.850000
# 121               Tanzania       8.800000
# 115                  Sudan       8.700000
# 37       Equatorial Guinea       8.700000
# 49                Guernsey       8.692308
# 133                Uruguay       8.675000
# 68                  Kosovo       8.625000
# 119                 Taiwan       8.616667
# 43                 Georgia       8.600000
# 17                 Bermuda       8.600000
# 50                   Haiti       8.600000

# %%
px.bar(nationality_avg,
             x='Reviewer Nationality',
             y='Average Score',
             text_auto=True)

# %% [markdown]
# **Which nationalities write the longest reviews (positive + negative word counts)?**

# %%
nationality_length = df.groupby('Reviewer Nationality') \
    [['Review Total Positive Word Counts', 'Review Total Negative Word Counts']].sum() \
    .sum(axis=1) \
    .reset_index(name='Total_Review_Words') \
    .sort_values(by='Total_Review_Words', ascending=False).head(20)
nationality_length
# Out:
#          Reviewer Nationality  Total_Review_Words
# 130            United Kingdom              246246
# 132  United States of America               41010
# 9                   Australia               22203
# 58                    Ireland               17411
# 44                    Germany               10207
# 88                Netherlands                9091
# 25                     Canada                9042
# 129      United Arab Emirates                8987
# 117               Switzerland                8545
# 60                     Israel                6491
# 42                     France                6389
# 125                    Turkey                5799
# 105              Saudi Arabia                5684
# 16                    Belgium                5301
# 104                    Russia                4960
# 113                     Spain                4704
# 103                   Romania                4444
# 61                      Italy                4443
# 116                    Sweden                4401
# 69                     Kuwait                4069

# %%
px.bar(nationality_length,
             x='Reviewer Nationality',
             y='Total_Review_Words',
             text_auto=True,
             title='Top 20 Nationalities by Total Review Word Counts')

# %% [markdown]
# **Do higher reviewer levels give more positive reviews?**

# %%
df['Reviewer Level'].unique()
# Out:
# array(['High', 'Intermediate', 'Low'], dtype=object)

# %%
df.groupby('Reviewer Level')['Sentiment Label'].value_counts(normalize=True)
# Out:
# Reviewer Level  Sentiment Label
# High            Positive           0.725773
#                 Negative           0.244531
#                 Neutral            0.029696
# Intermediate    Negative           0.682749
#                 Positive           0.283425
#                 Neutral            0.033826
# Low             Negative           0.880952
#                 Positive           0.091837
#                 Neutral            0.027211
# Name: proportion, dtype: float64

# %%
sentiment_pct = df.groupby('Reviewer Level')['Sentiment Label'] \
                  .value_counts(normalize=True) \
                  .rename('Percentage') \
                  .reset_index()

fig = px.bar(
    sentiment_pct,
    x='Reviewer Level',
    y='Percentage',
    color='Reviewer Level',  
    barmode='group',
    facet_col='Sentiment Label',
    text='Percentage'
)

fig.update_traces(texttemplate='%{text:.2f}')
fig.show()

# %%
df.head(3)
# Out:
#                            Hotel Address  Additional Number of Scoring  \
# 0     43 Rue des Mathurins 8th arr 75008                           135
# 1     Provincialeweg 38 Zuidoost 1108 AB                           245
# 2  Jan Luijkenstraat 76 Oud Zuid 1071 CT                           146
#
#   Review Date  Average Score                        Hotel Name  \
# 0  2016-04-11            8.6             Le Mathurin Hotel Spa
# 1  2016-07-26            7.5  Golden Tulip Amsterdam Riverside
# 2  2016-02-09            8.8                     Hotel JL No76
#
#   Reviewer Nationality                                    Negative Review  \
# 0              Germany                                        No Negative
# 1       United Kingdom   the location wasnt very good it was 20 minute...
# 2              Ireland                                        No Negative
#
#    Review Total Negative Word Counts  Total Number of Reviews  \
# 0                                  0                     1184
# 1                                 67                     2362
# 2                                  0                      914
#
#                                      Positive Review  \
# 0   Great Rooms with a nice bathroom Room was pre...
# 1   The hotel was lovely would have to say it sho...
# 2   The hotel is well located near the Museum Qua...
#
#    Review Total Positive Word Counts  \
# 0                                 40
# 1                                 68
# 2                                 18
#
#    Total Number of Reviews Reviewer Has Given  days since review        lat  \
# 0                                          12                479  48.873207
# 1                                           1                373  52.315453
# 2                                           5                541  52.359592
#
#         lng      Country       City Reviewer Level  Nights Stayed  \
# 0  2.323901       France      Paris           High            2.0
# 1  4.996300  Netherlands  Amsterdam   Intermediate            3.0
# 2  4.880159  Netherlands  Amsterdam   Intermediate            3.0
#
#   Traveler Type     Trip Type                    Room Type  Review Year  \
# 0        Couple  Leisure trip  Classic Double or Twin Room         2016
# 1        Couple  Leisure trip           Standard Twin Room         2016
# 2        Couple  Leisure trip  Comfort Double or Twin Room         2016
#
#    Review Month  Review Day  Season  Hotel Popularity Score Sentiment Label  \
# 0             4          11  Spring                 10182.4        Positive
# 1             7          26  Summer                 17715.0        Positive
# 2             2           9  Winter                  8043.2        Positive
#
#   Stay Length Category Room Type Category
# 0           Short Stay             Double
# 1          Medium Stay              Other
# 2          Medium Stay             Double

# %% [markdown]
# **Which nationalities contribute the most total reviews?**

# %%
df.columns
# Out:
# Index(['Hotel Address', 'Additional Number of Scoring', 'Review Date',
#        'Average Score', 'Hotel Name', 'Reviewer Nationality',
#        'Negative Review', 'Review Total Negative Word Counts',
#        'Total Number of Reviews', 'Positive Review',
#        'Review Total Positive Word Counts',
#        'Total Number of Reviews Reviewer Has Given', 'days since review',
#        'lat', 'lng', 'Country', 'City', 'Reviewer Level', 'Nights Stayed',
#        'Traveler Type', 'Trip Type', 'Room Type', 'Review Year',
#        'Review Month', 'Review Day', 'Season', 'Hotel Popularity Score',
#        'Sentiment Label', 'Stay Length Category', 'Room Type Category'],
#       dtype='object')

# %%
top_nat = df.groupby('Reviewer Nationality').size() \
            .reset_index(name='Review Count') \
            .sort_values(by='Review Count', ascending=False).head(10)
top_nat
# Out:
#          Reviewer Nationality  Review Count
# 130            United Kingdom          6893
# 132  United States of America           948
# 9                   Australia           601
# 58                    Ireland           428
# 129      United Arab Emirates           288
# 44                    Germany           261
# 88                Netherlands           247
# 105              Saudi Arabia           234
# 117               Switzerland           231
# 25                     Canada           228

# %%
px.bar(
    top_nat,
    x='Reviewer Nationality',
    y='Review Count',
    text='Review Count',
    color='Reviewer Nationality'   
).update_layout(
    title='Top 10 Nationalities by Total Reviews',
    xaxis_title='Reviewer Nationality',
    yaxis_title='Number of Reviews'
)

# %% [markdown]
# ## **Group 3 — Seasonal & Date-Based Insights**

# %% [markdown]
# **How do sentiment labels (Positive, Negative, Neutral) vary across seasons?**

# %%
season_sentiment_pct = df.groupby('Season')['Sentiment Label'] \
                         .value_counts(normalize=True) \
                         .rename('Percentage') \
                         .reset_index()
season_sentiment_pct
# Out:
#     Season Sentiment Label  Percentage
# 0   Autumn        Positive    0.515683
# 1   Autumn        Negative    0.451415
# 2   Autumn         Neutral    0.032903
# 3   Spring        Positive    0.528266
# 4   Spring        Negative    0.442521
# 5   Spring         Neutral    0.029213
# 6   Summer        Positive    0.519465
# 7   Summer        Negative    0.452555
# 8   Summer         Neutral    0.027981
# 9   Winter        Positive    0.546711
# 10  Winter        Negative    0.417543
# 11  Winter         Neutral    0.035746

# %%
px.bar(
    season_sentiment_pct,
    x='Season',
    y='Percentage',
    color='Season',       
    barmode='group',
    facet_col='Sentiment Label',  
    text='Percentage'
).update_traces(texttemplate='%{text:.2f}').update_layout(title='Sentiment Distribution Across Seasons')

# %% [markdown]
# **How do average review scores change by review year?**

# %%
avg_score_by_year = df.groupby('Review Year')['Average Score'].mean().reset_index()
avg_score_by_year
# Out:
#    Review Year  Average Score
# 0         2015       8.381267
# 1         2016       8.401389
# 2         2017       8.410795

# %%
px.line(
    avg_score_by_year,
    x='Review Year',
    y='Average Score',
    markers=True,   
    title='Average Review Scores Over Years'
).update_layout(yaxis_title='Average Score', xaxis_title='Review Year')

# %% [markdown]
# **Are positive/negative word counts seasonal?**

# %%
season_word_counts = df.groupby('Season')[['Review Total Positive Word Counts',
                                           'Review Total Negative Word Counts']].mean().reset_index()
season_word_counts
# Out:
#    Season  Review Total Positive Word Counts  \
# 0  Autumn                          15.903444
# 1  Spring                          18.744928
# 2  Summer                          17.739903
# 3  Winter                          17.383899
#
#    Review Total Negative Word Counts
# 0                          18.138991
# 1                          19.333514
# 2                          18.727981
# 3                          17.284470

# %%
season_word_counts_long = season_word_counts.melt(
    id_vars='Season',
    value_vars=['Review Total Positive Word Counts', 'Review Total Negative Word Counts'],
    var_name='Word Type',
    value_name='Average Count'
)

fig = px.bar(
    season_word_counts_long,
    x='Season',
    y='Average Count',
    color='Season',          
    facet_col='Word Type',   
    text='Average Count'
)

fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(title='Average Positive and Negative Word Counts by Season ')

fig.show()

# %% [markdown]
# **Do certain months have higher negative sentiment?**

# %%
df.columns
# Out:
# Index(['Hotel Address', 'Additional Number of Scoring', 'Review Date',
#        'Average Score', 'Hotel Name', 'Reviewer Nationality',
#        'Negative Review', 'Review Total Negative Word Counts',
#        'Total Number of Reviews', 'Positive Review',
#        'Review Total Positive Word Counts',
#        'Total Number of Reviews Reviewer Has Given', 'days since review',
#        'lat', 'lng', 'Country', 'City', 'Reviewer Level', 'Nights Stayed',
#        'Traveler Type', 'Trip Type', 'Room Type', 'Review Year',
#        'Review Month', 'Review Day', 'Season', 'Hotel Popularity Score',
#        'Sentiment Label', 'Stay Length Category', 'Room Type Category'],
#       dtype='object')

# %%
df['Sentiment Label'].unique()
# Out:
# array(['Positive', 'Negative', 'Neutral'], dtype=object)

# %%
negative_per_month = df[df['Sentiment Label'] == 'Negative'] \
                        .groupby('Review Month').size().reset_index(name='Negative Reviews').sort_values(by='Negative Reviews',ascending=False)
negative_per_month
# Out:
#     Review Month  Negative Reviews
# 7              8               672
# 6              7               626
# 4              5               584
# 2              3               534
# 8              9               534
# 5              6               525
# 3              4               525
# 9             10               511
# 11            12               473
# 1              2               470
# 0              1               465
# 10            11               435

# %%
px.bar(
    negative_per_month,
    x='Review Month',
    y='Negative Reviews',
    title='Distribution of Negative Reviews by Month',
    color='Negative Reviews',text_auto=True
)

# %%
positive_per_month = df[df['Sentiment Label'] == 'Positive'] \
                        .groupby('Review Month').size() \
                        .reset_index(name='Positive Reviews') \
                        .sort_values(by='Positive Reviews', ascending=False)


fig = px.bar(
    positive_per_month,
    x='Review Month',
    y='Positive Reviews',
    color='Positive Reviews',
    text_auto=True,
    title='Months with Highest Positive Reviews'
)

fig.show()

# %% [markdown]
# ## **Group 4 — Stay Characteristics**

# %% [markdown]
# **Which traveler types submit the most reviews?**

# %%
df.columns
# Out:
# Index(['Hotel Address', 'Additional Number of Scoring', 'Review Date',
#        'Average Score', 'Hotel Name', 'Reviewer Nationality',
#        'Negative Review', 'Review Total Negative Word Counts',
#        'Total Number of Reviews', 'Positive Review',
#        'Review Total Positive Word Counts',
#        'Total Number of Reviews Reviewer Has Given', 'days since review',
#        'lat', 'lng', 'Country', 'City', 'Reviewer Level', 'Nights Stayed',
#        'Traveler Type', 'Trip Type', 'Room Type', 'Review Year',
#        'Review Month', 'Review Day', 'Season', 'Hotel Popularity Score',
#        'Sentiment Label', 'Stay Length Category', 'Room Type Category'],
#       dtype='object')

# %%
traveler_counts = df.groupby('Traveler Type')['Sentiment Label'].count().reset_index(name='Review Count').sort_values(by='Review Count',ascending=False)
traveler_counts
# Out:
#                 Traveler Type  Review Count
# 0                      Couple          7107
# 4               Solo traveler          3020
# 3                       Group          1821
# 2  Family with young children          1693
# 1  Family with older children           747

# %%
px.bar(
    traveler_counts,
    x='Review Count',
    y='Traveler Type',
    orientation='h',   
    color='Traveler Type',
    text='Review Count',
    title='Review Counts by Traveler Type'
).update_traces(texttemplate='%{text}', textposition='outside')

# %% [markdown]
# **How does the sentiment of reviews (Positive, Negative, Neutral) vary across different traveler types?**

# %%
traveler_sentiment_pct = df.groupby('Traveler Type')['Sentiment Label'] \
                           .value_counts(normalize=True) \
                           .rename('Percentage') \
                           .reset_index()
traveler_sentiment_pct
# Out:
#                  Traveler Type Sentiment Label  Percentage
# 0                       Couple        Positive    0.537920
# 1                       Couple        Negative    0.433657
# 2                       Couple         Neutral    0.028423
# 3   Family with older children        Positive    0.530120
# 4   Family with older children        Negative    0.439090
# 5   Family with older children         Neutral    0.030790
# 6   Family with young children        Positive    0.514471
# 7   Family with young children        Negative    0.451270
# 8   Family with young children         Neutral    0.034259
# 9                        Group        Positive    0.557386
# 10                       Group        Negative    0.405272
# 11                       Group         Neutral    0.037342
# 12               Solo traveler        Positive    0.490066
# 13               Solo traveler        Negative    0.477483
# 14               Solo traveler         Neutral    0.032450

# %%
px.bar(
    traveler_sentiment_pct,
    x='Percentage',
    y='Traveler Type',
    color='Traveler Type',
    orientation='h',
    facet_col='Sentiment Label',  
    text='Percentage'
).update_traces(texttemplate='%{text:.2f}', textposition='outside').update_layout(title='Sentiment Distribution by Traveler Type')

# %% [markdown]
# **Which room types receive the highest satisfaction scores?**

# %%
room_avg_score = df.groupby('Room Type Category')['Average Score'].mean().reset_index().sort_values(by='Average Score',ascending=False)
room_avg_score
# Out:
#    Room Type Category  Average Score
# 9              Studio       8.612281
# 5           King Room       8.608342
# 10              Suite       8.601570
# 2      Deluxe/Comfort       8.478957
# 1           Connected       8.450000
# 0           Apartment       8.436735
# 3              Double       8.404817
# 6               Other       8.357094
# 4              Family       8.314103
# 11             Triple       8.211673
# 7           Quadruple       8.125490
# 8              Single       8.096774

# %%
px.bar(
    room_avg_score,
    x='Room Type Category',
    y='Average Score',
    text='Average Score',
    color='Average Score',
    title='Average Review Scores by Room Type Category'
).update_traces(texttemplate='%{text:.2f}', textposition='outside').update_layout(xaxis_title='Room Type Category', yaxis_title='Average Score')

# %% [markdown]
# **How does the sentiment of reviews (Positive, Negative, Neutral) vary across different room types?**

# %%
room_sentiment_counts = df.groupby(['Room Type Category', 'Sentiment Label']) \
                          .size() \
                          .reset_index(name='Review Count').sort_values(by='Review Count',ascending=False)
room_sentiment_counts
# Out:
#    Room Type Category Sentiment Label  Review Count
# 10             Double        Positive          4464
# 8              Double        Negative          3669
# 19              Other        Positive          1324
# 17              Other        Negative          1200
# 16          King Room        Positive           553
# 14          King Room        Negative           430
# 25             Single        Positive           365
# 23             Single        Negative           325
# 7      Deluxe/Comfort        Positive           284
# 5      Deluxe/Comfort        Negative           275
# 31              Suite        Positive           258
# 9              Double         Neutral           254
# 29              Suite        Negative           172
# 34             Triple        Positive           130
# 32             Triple        Negative           121
# 18              Other         Neutral            91
# 13             Family        Positive            84
# 28             Studio        Positive            65
# 11             Family        Negative            65
# 26             Studio        Negative            44
# 22          Quadruple        Positive            27
# 15          King Room         Neutral            24
# 0           Apartment        Negative            23
# 24             Single         Neutral            23
# 20          Quadruple        Negative            22
# 2           Apartment        Positive            21
# 30              Suite         Neutral            16
# 6      Deluxe/Comfort         Neutral            16
# 4           Connected        Positive            10
# 3           Connected        Negative             8
# 12             Family         Neutral             7
# 33             Triple         Neutral             6
# 1           Apartment         Neutral             5
# 27             Studio         Neutral             5
# 21          Quadruple         Neutral             2

# %%
px.bar(
    room_sentiment_counts,
    x='Room Type Category',
    y='Review Count',
    color='Sentiment Label',   
    text='Review Count',
    barmode='group',           
    title='Review Counts by Room Type and Sentiment'
).update_traces(texttemplate='%{text}', textposition='outside').update_layout(xaxis_title='Room Type Category', yaxis_title='Number of Reviews')

# %% [markdown]
# **Do business trips have different sentiment patterns compared to leisure trips?**

# %%
trip_sentiment_pct = df.groupby('Trip Type')['Sentiment Label'] \
                       .value_counts(normalize=True) \
                       .rename('Percentage') \
                       .reset_index()
trip_sentiment_pct
# Out:
#        Trip Type Sentiment Label  Percentage
# 0  Business trip        Negative    0.509053
# 1  Business trip        Positive    0.449383
# 2  Business trip         Neutral    0.041564
# 3   Leisure trip        Positive    0.542984
# 4   Leisure trip        Negative    0.427914
# 5   Leisure trip         Neutral    0.029102

# %%
px.bar(
    trip_sentiment_pct,
    x='Trip Type',
    y='Percentage',
    color='Trip Type',
    facet_col='Sentiment Label',  # Positive / Negative / Neutral
    text='Percentage'
).update_traces(texttemplate='%{text:.2f}', textposition='outside').update_layout(title='Sentiment Distribution by Trip Type')

# %%
df.columns
# Out:
# Index(['Hotel Address', 'Additional Number of Scoring', 'Review Date',
#        'Average Score', 'Hotel Name', 'Reviewer Nationality',
#        'Negative Review', 'Review Total Negative Word Counts',
#        'Total Number of Reviews', 'Positive Review',
#        'Review Total Positive Word Counts',
#        'Total Number of Reviews Reviewer Has Given', 'days since review',
#        'lat', 'lng', 'Country', 'City', 'Reviewer Level', 'Nights Stayed',
#        'Traveler Type', 'Trip Type', 'Room Type', 'Review Year',
#        'Review Month', 'Review Day', 'Season', 'Hotel Popularity Score',
#        'Sentiment Label', 'Stay Length Category', 'Room Type Category'],
#       dtype='object')

# %% [markdown]
# **Which traveler type leaves the most positive word counts?**

# %%
positive_words = df.groupby('Trip Type')['Review Total Positive Word Counts'].sum().reset_index().sort_values(by='Review Total Positive Word Counts',ascending=False)
positive_words
# Out:
#        Trip Type  Review Total Positive Word Counts
# 1   Leisure trip                             219169
# 0  Business trip                              32631

# %%
px.pie(
    positive_words,
    names='Trip Type',
    values='Review Total Positive Word Counts',
    title='Total Positive Word Counts by Trip Type'
)

# %% [markdown]
# **Which trip type contributes the most positive words in reviews?**

# %%
negative_words = df.groupby('Trip Type')['Review Total Negative Word Counts'] \
                   .sum().reset_index() \
                   .sort_values(by='Review Total Negative Word Counts', ascending=False)
negative_words
# Out:
#        Trip Type  Review Total Negative Word Counts
# 1   Leisure trip                             219838
# 0  Business trip                              45138

# %%
px.bar(
    negative_words,
    x='Review Total Negative Word Counts',
    y='Trip Type',
    orientation='h',
    color='Trip Type',
    text='Review Total Negative Word Counts',
    title='Total Negative Word Counts by Trip Type'
).update_traces(texttemplate='%{text}', textposition='outside')

# %% [markdown]
# ## **Group 5 — Text & Sentiment Insights**

# %% [markdown]
# **Which hotels have the highest positive word counts?**

# %%
top_hotels_positive = df.groupby('Hotel Name')['Review Total Positive Word Counts'].sum().reset_index().sort_values(by='Review Total Positive Word Counts',ascending=False).head(10)
top_hotels_positive
# Out:
#                                              Hotel Name  \
# 1051               Park Plaza Westminster Bridge London
# 1186                                Strand Palace Hotel
# 173          Britannia International Hotel Canary Wharf
# 146                  Best Western Premier Hotel Couture
# 227              Copthorne Tara Hotel London Kensington
# 347                       Grand Royale London Hyde Park
# 263   DoubleTree by Hilton Hotel London Tower of London
# 1287                   The Student Hotel Amsterdam City
# 768                      Intercontinental London The O2
# 265     DoubleTree by Hilton London Docklands Riverside
#
#       Review Total Positive Word Counts
# 1051                               2271
# 1186                               1701
# 173                                1506
# 146                                1442
# 227                                1404
# 347                                1349
# 263                                1346
# 1287                               1264
# 768                                1173
# 265                                1098

# %%
px.bar(
    top_hotels_positive,
    x='Hotel Name',
    y='Review Total Positive Word Counts',
    text='Review Total Positive Word Counts',
    title='Top 10 Hotels by Positive Word Counts'
).update_layout(xaxis_title='Hotel Name', yaxis_title='Total Positive Word Counts')

# %% [markdown]
# **Which hotels have the highest Nigative word counts?**

# %%
top_hotels_nigative = df.groupby('Hotel Name')['Review Total Negative Word Counts'].sum().reset_index().sort_values(by='Review Total Negative Word Counts',ascending=False).head(10)
top_hotels_nigative
# Out:
#                                              Hotel Name  \
# 173          Britannia International Hotel Canary Wharf
# 1051               Park Plaza Westminster Bridge London
# 1186                                Strand Palace Hotel
# 1043                      Park Plaza County Hall London
# 347                       Grand Royale London Hyde Park
# 227              Copthorne Tara Hotel London Kensington
# 496                       Holiday Inn London Kensington
# 481                             Hilton London Metropole
# 164                                 Blakemore Hyde Park
# 263   DoubleTree by Hilton Hotel London Tower of London
#
#       Review Total Negative Word Counts
# 173                                3279
# 1051                               2606
# 1186                               2462
# 1043                               2420
# 347                                2405
# 227                                2130
# 496                                2100
# 481                                1985
# 164                                1769
# 263                                1672

# %%
px.bar(
    top_hotels_nigative,
    x='Hotel Name',
    y='Review Total Negative Word Counts',
    text='Review Total Negative Word Counts',
    title='Top 10 Hotels by Nigative Word Counts'
).update_layout(xaxis_title='Hotel Name', yaxis_title='Total Nigative Word Counts')

# %% [markdown]
# **Which cities show more negative sentiment in reviews?**

# %%
df['Sentiment Label'].unique()
# Out:
# array(['Positive', 'Negative', 'Neutral'], dtype=object)

# %%
negative_per_city = df[df['Sentiment Label'] == 'Negative'] \
                    .groupby('City').size() \
                    .reset_index(name='Negative Reviews') \
                    .sort_values(by='Negative Reviews', ascending=False)
negative_per_city
# Out:
#         City  Negative Reviews
# 4     United              3426
# 1  Barcelona               709
# 3      Paris               699
# 0  Amsterdam               696
# 2      Milan               431
# 5     Vienna               393

# %%
px.bar(
    negative_per_city,
    x='City',
    y='Negative Reviews',
    text='Negative Reviews',
    color='City',
    title='Top Cities by Negative Reviews'
).update_layout(xaxis_title='City', yaxis_title='Number of Negative Reviews')

# %% [markdown]
# **Which cities show more Postive sentiment in reviews?**

# %%
postive_per_city = df[df['Sentiment Label'] == 'Positive'] \
                    .groupby('City').size() \
                    .reset_index(name='Positive Reviews') \
                    .sort_values(by='Positive Reviews', ascending=False)
postive_per_city
# Out:
#         City  Positive Reviews
# 4     United              3631
# 1  Barcelona               967
# 0  Amsterdam               922
# 3      Paris               916
# 2      Milan               583
# 5     Vienna               566

# %%
px.bar(
    postive_per_city,
    x='City',
    y='Positive Reviews',
    text='Positive Reviews',
    color='City',
    title='Top Cities by Positive Reviews'
).update_layout(xaxis_title='City', yaxis_title='Number of Positive Reviews')
